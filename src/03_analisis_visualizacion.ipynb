# %% [markdown]
# ## CrimePredic
#
# ### Análisis y Predicción Temporal de la Criminalidad en Municipios Españoles

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_5 = pd.read_csv("../data/processed/df_final_poblacion.csv")

df_5
# Out:
#       Municipio            Delitos   Año Periodo Trimestral  Trimestre  \
# 0       Alaquàs   Delitos Sexuales  2021        Enero-Marzo          1
# 1       Alaquàs   Delitos Sexuales  2021        Enero-Junio          2
# 2       Alaquàs   Delitos Sexuales  2021   Enero-Septiembre          3
# 3       Alaquàs   Delitos Sexuales  2021    Enero-Diciembre          4
# 4       Alaquàs   Delitos Sexuales  2022        Enero-Marzo          1
# ...         ...                ...   ...                ...        ...
# 36239    Xàtiva  Trafico De Drogas  2024   Enero-Septiembre          3
# 36240    Xàtiva  Trafico De Drogas  2024    Enero-Diciembre          4
# 36241    Xàtiva  Trafico De Drogas  2025        Enero-Marzo          1
# 36242    Xàtiva  Trafico De Drogas  2025        Enero-Junio          2
# 36243    Xàtiva  Trafico De Drogas  2025   Enero-Septiembre          3
#
#       Provincia  Total  Valor trimestral Poblacion
# 0      Valencia      2               2.0     29649
# 1      Valencia      2               0.0     29649
# 2      Valencia      2               0.0     29649
# 3      Valencia      4               2.0     29649
# 4      Valencia      0               0.0     29537
# ...         ...    ...               ...       ...
# 36239  Valencia      2               0.0     30378
# 36240  Valencia      4               2.0     30378
# 36241  Valencia      2               2.0     31008
# 36242  Valencia      3               1.0     31008
# 36243  Valencia      3               0.0     31008
#
# [36244 rows x 9 columns]

# %% [markdown]
# # Análisis Univariante.
#
# > - La variable objetivo `Valor trimestral` representa el número total de delitos registrados por tipología, ámbito geográfico y periodo temporal. Su distribución presenta una fuerte asimetría positiva, con una elevada concentración de valores bajos y la presencia de valores extremos, lo cual es característico de variables de conteo asociadas a fenómenos poco frecuentes en determinadas combinaciones espaciales y temporales.

# %%
df_5['Valor trimestral'].describe().T
# Out:
# count    36244.000000
# mean       176.496524
# std       1501.786644
# min        -62.000000
# 25%          1.000000
# 50%          6.000000
# 75%         37.000000
# max      31495.000000
# Name: Valor trimestral, dtype: float64

# %% [markdown]
# La variable objetivo `Valor trimestral` presenta una distribución fuertemente asimétrica a la derecha. La media (297,4) es superior a la mediana (16), lo que indica la presencia de valores extremos que concentran gran parte del volumen total de delitos. Asimismo, el 75% de los registros presenta valores inferiores a 91, mientras que el valor máximo alcanza los 112,272 delitos. Esta elevada dispersión, junto con la presencia de numerosos valores bajos y nulos, es característica de variables de conteo asociadas a fenómenos heterogéneos en el espacio y el tiempo

# %% [markdown]
# # ANÁLISIS BIVARIANTE
#
# > - `Año` - `Valor trimestral`.

# %%
df_5.groupby('Año')['Valor trimestral'].sum()
# Out:
# Año
# 2016    588446.0
# 2017    731392.0
# 2018    772441.0
# 2019    779968.0
# 2020    448633.0
# 2021    541755.0
# 2022    683601.0
# 2023    700949.0
# 2024    665925.0
# 2025    483830.0
# Name: Valor trimestral, dtype: float64

# %% [markdown]
# El análisis bivariante entre la variable `Valor Trimestral` y el `Año` muestra una tendencia creciente en el volumen total de delitos desde 2016 hasta 2019. En 2020 se observa una caída abrupta que rompe el patrón previo, seguida de una recuperación en los años posteriores, alcanzando un máximo en 2023. `(700,949)`
# > - Los valores del 2025 estan incompletos, pendientes a subir por la plataforma Policía Municipal. Datos estadísticos de la Policía Municipal. ya que corresponden al ultimo trimestre incompleto.

# %% [markdown]
# > - `Poblacion` - `Valor trimestral`

# %%
df_5.groupby('Poblacion')['Valor trimestral'].mean()
# Out:
# Poblacion
# 1,825,332     394.925926
# 1,836,459    1580.000000
# 1,838,819     395.814815
# 1,858,683     396.888889
# 1,879,888     190.111111
#                 ...
# 98,533        144.481481
# 98086          53.833333
# 98590          49.555556
# 98621          59.333333
# 99037          43.259259
# Name: Valor trimestral, Length: 1097, dtype: float64

# %% [markdown]
# El análisis bivariante entre `población` y `Valor trimestral` de delitos muestra una relación positiva clara: los municipios con mayor población presentan, en promedio, un mayor número absoluto de delitos. Este comportamiento es consistente con la naturaleza agregada de la variable Total y refleja un efecto de escala poblacional más que un mayor nivel relativo de criminalidad. Por tanto, la población actúa como un factor estructural explicativo del volumen de delitos, pero no permite por sí sola evaluar el riesgo o la intensidad delictiva sin normalización.

# %% [markdown]
# > - `Trimeste` - `Valor trimestral`.

# %%
df_5.groupby('Trimestre')['Valor trimestral'].mean()
# Out:
# Trimestre
# 1    172.362656
# 2    168.765334
# 3    180.108179
# 4    185.449660
# Name: Valor trimestral, dtype: float64

# %% [markdown]
# Se observa un incremento progresivo del volumen medio de delitos: (Patron ordenado)
#
# > - T1 → Nivel Medio
# > - T2 → Nivel bajo
# > - T3 → aumento significativo
# > - T4 → máximo del año

# %% [markdown]
# El análisis bivariante entre la variable `Valor trimestral` y el `Trimestre` muestra un patrón estacional claramente definido. El volumen medio de delitos aumenta de forma progresiva desde el primer hasta el cuarto trimestre, alcanzando su valor máximo en T4. Esta evolución sugiere la existencia de una estacionalidad marcada en la distribución de los delitos, lo que justifica la inclusión del trimestre como variable explicativa en el análisis posterior.

# %% [markdown]
# > - `Provincia` - `Valor trimestral`.

# %%
df_5.groupby('Provincia')['Valor trimestral'].mean()
# Out:
# Provincia
# Alicante      55.946788
# Barcelona    215.642934
# Castellón     15.934325
# Madrid       275.718578
# Valencia      61.268387
# Name: Valor trimestral, dtype: float64

# %% [markdown]
# Diferencias claras entre provincias
#
# > - Madrid presenta el valor medio más alto de delitos.
# > - Barcelona presenta el valor medio de delitos.
# > - Alicante y Valencia muestran valores medios muy similares entre sí.
# > - Castellon presenta el valor mas bajo en delitos.
# > - La diferencia de Madrid respecto a las otras provincias es sistemática.

# %% [markdown]
# El análisis bivariante entre la variable `Valor trimestral` y la `Provincia` revela diferencias significativas en el volumen medio de delitos registrados. Madrid presenta el valor medio más elevado, mientras que Alicante y Valencia muestran niveles similares entre sí. Estos resultados evidencian una heterogeneidad territorial en la distribución de los delitos, lo que justifica la inclusión de la provincia como variable explicativa en el análisis posterior.

# %% [markdown]
# > - `Delitos` - `Valor trimestral`.

# %%
df_5.groupby('Delitos')['Valor trimestral'].mean()
# Out:
# Delitos
# Daños                        490.532020
# Delitos Sexuales              20.857860
# Homicidios                     1.178553
# Hurtos                      1092.372521
# Lesiones                      24.574837
# Robos Con Fuerza             187.026118
# Robos Con Violencia          126.566801
# Secuestro                      0.068559
# Sustraccion De Vehiculos      52.029131
# Trafico De Drogas             21.094174
# Name: Valor trimestral, dtype: float64

# %% [markdown]
# ## Diferencias entre categorías:
#
# > - Hurtos y Daños presentan valores medios muy superiores al resto.
# > - Tipologías violentas graves (homicidios, secuestros) tienen medias muy bajas.
# > - Existe una clara separación entre: delitos frecuentes y delitos graves poco frecuentes

# %% [markdown]
# El análisis bivariante entre la variable `Valor trimestral` y la tipología de `Delitos` revela una marcada heterogeneidad entre categorías. Delitos como hurtos y daños concentran los valores medios más elevados, mientras que tipologías de mayor gravedad, como homicidios o secuestros, presentan valores medios significativamente inferiores. Esta distribución desigual pone de manifiesto que el volumen total de delitos se encuentra fuertemente concentrado en un número reducido de tipologías, justificando la inclusión de esta variable como uno de los principales factores explicativos del modelo.

# %%
top_10_municipios = (df_5.groupby('Municipio')['Valor trimestral'].sum().sort_values(ascending=False).head(10))

top_10_municipios
# Out:
# Municipio
# Madrid                          2373334.0
# Barcelona                       2166930.0
# Valencia                         274628.0
# Alicante                          96455.0
# Hospitalet de Llobregat (L')      93059.0
# Badalona                          61287.0
# Prat de Llobregat (El)            59716.0
# Leganés                           44915.0
# Elche                             41149.0
# Sabadell                          40036.0
# Name: Valor trimestral, dtype: float64

# %% [markdown]
# El análisis de los municipios con mayor volumen total de delitos muestra una clara concentración de la criminalidad en grandes núcleos urbanos y áreas metropolitanas. Madrid y Barcelona son las que mas destacan sobre el resto de municipios, seguidos por otras ciudades de gran tamaño como Valencia, Alicante o Elche, así como municipios. Estos resultados evidencian una distribución espacial altamente desigual del fenómeno delictivo, influida por la densidad urbana y la actividad socioeconómica.

# %%
top_10_municipios_tranquilos = (df_5.groupby('Municipio')['Valor trimestral'].sum().sort_values(ascending=True).head(10))

top_10_municipios_tranquilos
# Out:
# Municipio
# Silla                    227.0
# Calella                  439.0
# Vila-Real                531.0
# Castellar del Vallès     581.0
# Manlleu                  601.0
# Puçol                    636.0
# Sant Just Desvern        736.0
# Olesa de Montserrat      738.0
# Esparreguera             761.0
# San Martín de la Vega    802.0
# Name: Valor trimestral, dtype: float64

# %% [markdown]
# El análisis de los municipios con menor volumen total de delitos muestra que la criminalidad se concentra en menor medida en localidades de pequeño tamaño y baja densidad urbana. Los valores observados son reducidos y relativamente homogéneos, en contraste con la fuerte concentración detectada en grandes núcleos urbanos. Este resultado refuerza la existencia de una marcada desigualdad territorial en la distribución del fenómeno delictivo.

# %%
df_5
# Out:
#       Municipio            Delitos   Año Periodo Trimestral  Trimestre  \
# 0       Alaquàs   Delitos Sexuales  2021        Enero-Marzo          1
# 1       Alaquàs   Delitos Sexuales  2021        Enero-Junio          2
# 2       Alaquàs   Delitos Sexuales  2021   Enero-Septiembre          3
# 3       Alaquàs   Delitos Sexuales  2021    Enero-Diciembre          4
# 4       Alaquàs   Delitos Sexuales  2022        Enero-Marzo          1
# ...         ...                ...   ...                ...        ...
# 36239    Xàtiva  Trafico De Drogas  2024   Enero-Septiembre          3
# 36240    Xàtiva  Trafico De Drogas  2024    Enero-Diciembre          4
# 36241    Xàtiva  Trafico De Drogas  2025        Enero-Marzo          1
# 36242    Xàtiva  Trafico De Drogas  2025        Enero-Junio          2
# 36243    Xàtiva  Trafico De Drogas  2025   Enero-Septiembre          3
#
#       Provincia  Total  Valor trimestral Poblacion
# 0      Valencia      2               2.0     29649
# 1      Valencia      2               0.0     29649
# 2      Valencia      2               0.0     29649
# 3      Valencia      4               2.0     29649
# 4      Valencia      0               0.0     29537
# ...         ...    ...               ...       ...
# 36239  Valencia      2               0.0     30378
# 36240  Valencia      4               2.0     30378
# 36241  Valencia      2               2.0     31008
# 36242  Valencia      3               1.0     31008
# 36243  Valencia      3               0.0     31008
#
# [36244 rows x 9 columns]

# %% [markdown]
# ## Limpieza final de población.

# %%
df_5['Poblacion'] = (df_5['Poblacion'].astype(str).str.replace('.', '', regex=False).str.replace(',', '', regex=False).astype(float))

# %% [markdown]
# # Visualización

# %% [markdown]
# ## Visualización de variables numéricas

# %%
fig, axis = plt.subplots(1, 3, figsize=(22, 5))

sns.histplot(ax=axis[0], data=df_5, x='Valor trimestral', kde=True)
axis[0].set_title('Distribución de Valor Trimestral')
axis[0].set_ylabel(None)

sns.histplot(ax=axis[1], data=df_5, x='Total', kde=True)
axis[1].set_title('Distribución de Total')
axis[1].set_ylabel(None)

sns.histplot(ax=axis[2], data=df_5, x='Trimestre', discrete=True)
axis[2].set_title('Distribución por Trimestre')
axis[2].set_ylabel(None)



plt.tight_layout()
plt.show()

# %% [markdown]
# ## Visualización de variables categóricas

# %%
fig, axis = plt.subplots(1, 4, figsize=(26, 6))

sns.countplot(ax=axis[0], data=df_5, x='Provincia')
axis[0].set_title('Frecuencia por Provincia')
axis[0].tick_params(axis='x', rotation=45)

sns.countplot(ax=axis[1], data=df_5, x='Delitos')
axis[1].set_title('Frecuencia por Tipo de Delito')
axis[1].tick_params(axis='x', rotation=45)

sns.countplot(ax=axis[2], data=df_5, x='Periodo Trimestral')
axis[2].set_title('Frecuencia por Periodo Trimestral')
axis[2].tick_params(axis='x', rotation=45)


top_municipios = df_5['Municipio'].value_counts().head(10).index
sns.countplot(
    ax=axis[3],
    data=df_5[df_5['Municipio'].isin(top_municipios)],
    x='Municipio'
)
axis[3].set_title('Top 10 Municipios (frecuencia)')
axis[3].tick_params(axis='x', rotation=90)

plt.tight_layout()
plt.show()

# %%
top_municipios = (df_5.groupby('Municipio')['Valor trimestral'].sum().sort_values(ascending=False).head(10))

plt.figure(figsize=(10, 6))
sns.barplot(x=top_municipios.values,y=top_municipios.index)

plt.title('Top 10 municipios con mayor volumen de delitos')
plt.xlabel('Total de delitos Trimestrales')
plt.ylabel('Municipio')
plt.tight_layout()
plt.show()

# %%
bottom_10_municipios = (df_5.groupby('Municipio')['Valor trimestral'].sum().sort_values(ascending=True).head(10))

plt.figure(figsize=(10, 6))
sns.barplot(
    x=bottom_10_municipios.values,
    y=bottom_10_municipios.index
)

plt.title('Top 10 municipios con menor volumen de delitos')
plt.xlabel('Total de delitos Trimestrales')
plt.ylabel('Municipio')
plt.tight_layout()
plt.show()

# %%
top_municipios_provincia = (df_5.groupby(['Provincia', 'Municipio', 'Poblacion'])['Valor trimestral'].sum().reset_index().sort_values(['Provincia', 'Valor trimestral'], ascending=[True, False]))

top_municipios_provincia.groupby('Provincia').head(10)
# Out:
#       Provincia         Municipio  Poblacion  Valor trimestral
# 17     Alicante          Alicante  1950357.0           11001.0
# 13     Alicante          Alicante  1858683.0           10716.0
# 12     Alicante          Alicante  1838819.0           10687.0
# 10     Alicante          Alicante  1825332.0           10663.0
# 18     Alicante          Alicante  1991259.0           10657.0
# 11     Alicante          Alicante  1836459.0            9480.0
# 16     Alicante          Alicante  1901594.0            9413.0
# 19     Alicante          Alicante  2030037.0            9361.0
# 15     Alicante          Alicante  1881762.0            7633.0
# 14     Alicante          Alicante  1879888.0            6844.0
# 190   Barcelona         Barcelona  1636762.0          147973.0
# 198   Barcelona         Barcelona  5664579.0          147973.0
# 186   Barcelona         Barcelona  1620343.0          146902.0
# 197   Barcelona         Barcelona  5609350.0          146902.0
# 187   Barcelona         Barcelona  1620809.0          122876.0
# 196   Barcelona         Barcelona  5576037.0          122876.0
# 191   Barcelona         Barcelona  1660122.0          119333.0
# 202   Barcelona         Barcelona  5805500.0          119333.0
# 188   Barcelona         Barcelona  1636193.0          111276.0
# 200   Barcelona         Barcelona  5727615.0          111276.0
# 560   Castellón         Benicarló    28681.0             898.0
# 561   Castellón         Benicarló    29607.0             896.0
# 581   Castellón           Vinaròs    30278.0             824.0
# 580   Castellón           Vinaròs    29686.0             810.0
# 559   Castellón         Benicarló    27780.0             782.0
# 579   Castellón           Vinaròs    29120.0             745.0
# 558   Castellón         Benicarló    27658.0             593.0
# 578   Castellón           Vinaròs    28862.0             587.0
# 562   Castellón         Benicarló    30296.0             576.0
# 574   Castellón  Vall d'Uixó (la)    31733.0             545.0
# 739      Madrid            Madrid  3182981.0          149431.0
# 749      Madrid            Madrid  6507184.0          149431.0
# 741      Madrid            Madrid  3266126.0          146326.0
# 751      Madrid            Madrid  6663394.0          146326.0
# 740      Madrid            Madrid  3223334.0          144088.0
# 750      Madrid            Madrid  6578079.0          144088.0
# 738      Madrid            Madrid  3165541.0          128311.0
# 748      Madrid            Madrid  6466996.0          128311.0
# 742      Madrid            Madrid  3280782.0          122850.0
# 752      Madrid            Madrid  6750336.0          122850.0
# 1090   Valencia          Valencia  2656291.0           32884.0
# 1091   Valencia          Valencia  2709433.0           32859.0
# 1089   Valencia          Valencia  2605757.0           32263.0
# 1087   Valencia          Valencia  2589312.0           27934.0
# 1085   Valencia          Valencia  2547986.0           27672.0
# 1086   Valencia          Valencia  2565124.0           27380.0
# 1083   Valencia          Valencia  2540707.0           26769.0
# 1092   Valencia          Valencia  2758633.0           24637.0
# 1084   Valencia          Valencia  2544264.0           23822.0
# 1088   Valencia          Valencia  2591875.0           18408.0

# %% [markdown]
# ## Observaciones y concluciones:
#
# > - Las visualizaciones se organizaron diferenciando variables numéricas y categóricas, utilizando histogramas para analizar distribuciones y gráficos de frecuencia para variables discretas, con el objetivo de mejorar la interpretabilidad del análisis exploratorio.

# %% [markdown]
# ## ANÁLISIS MULTIVARIANTE
#
# > - Identificar dependencias
#
# > - Detectar redundancias
#
# > - Entender qué variables explican mejor el fenómeno
#
# > - Preparar el terreno para el modelado

# %% [markdown]
# ## MATRIZ DE CORRELACIÓN DE VARIABLES NUMERICAS

# %%
corr = df_5[['Año', 'Trimestre', 'Total', 'Valor trimestral', 'Poblacion']].corr()

plt.figure(figsize=(9, 7))
sns.heatmap(
    corr,
    annot=True,
    fmt=".2f",
    cmap="magma",
    linewidths=0.5
)

plt.title("Matriz de correlación entre variables numéricas")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Observaciones y concluciones
#
# > - La matriz de correlación muestra una fuerte relación positiva entre el `total de delitos` y el `valor trimestral` (r = 0.91), lo que indica una elevada redundancia informativa entre ambas variables. Por otro lado, la `población` presenta una correlación positiva moderada con el volumen de delitos `(0.35–0.38)`, coherente con un efecto de escala poblacional más que con una mayor intensidad delictiva. Las variables temporales (`año` y `trimestre`) muestran correlaciones débiles con el resto, lo que sugiere que el comportamiento delictivo no sigue una tendencia lineal simple en el tiempo.

# %% [markdown]
# ## Variable objetivo > `Valor Trimestral`
#
# > - representa el volumen real de criminalidad
# >
# > - Total de delitos registrados por municipio y trimestre.

# %% [markdown]
# A partir del análisis multivariante se selecciona Total como variable objetivo, al representar directamente el volumen de criminalidad. La variable Valor trimestral se excluye del modelado debido a su alta colinealidad con el objetivo. Se mantienen como variables explicativas la población y las variables temporales, así como las variables espaciales, al aportar información complementaria sin redundancia significativa.

# %%
df_5
# Out:
#       Municipio            Delitos   Año Periodo Trimestral  Trimestre  \
# 0       Alaquàs   Delitos Sexuales  2021        Enero-Marzo          1
# 1       Alaquàs   Delitos Sexuales  2021        Enero-Junio          2
# 2       Alaquàs   Delitos Sexuales  2021   Enero-Septiembre          3
# 3       Alaquàs   Delitos Sexuales  2021    Enero-Diciembre          4
# 4       Alaquàs   Delitos Sexuales  2022        Enero-Marzo          1
# ...         ...                ...   ...                ...        ...
# 36239    Xàtiva  Trafico De Drogas  2024   Enero-Septiembre          3
# 36240    Xàtiva  Trafico De Drogas  2024    Enero-Diciembre          4
# 36241    Xàtiva  Trafico De Drogas  2025        Enero-Marzo          1
# 36242    Xàtiva  Trafico De Drogas  2025        Enero-Junio          2
# 36243    Xàtiva  Trafico De Drogas  2025   Enero-Septiembre          3
#
#       Provincia  Total  Valor trimestral  Poblacion
# 0      Valencia      2               2.0    29649.0
# 1      Valencia      2               0.0    29649.0
# 2      Valencia      2               0.0    29649.0
# 3      Valencia      4               2.0    29649.0
# 4      Valencia      0               0.0    29537.0
# ...         ...    ...               ...        ...
# 36239  Valencia      2               0.0    30378.0
# 36240  Valencia      4               2.0    30378.0
# 36241  Valencia      2               2.0    31008.0
# 36242  Valencia      3               1.0    31008.0
# 36243  Valencia      3               0.0    31008.0
#
# [36244 rows x 9 columns]
