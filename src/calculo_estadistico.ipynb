# %%
import pandas as pd

# %%
df = pd.read_csv("../data/processed/df_final.csv")
df
# Out:
#                    Geografía   Año Provincia  Delitos Sexuales  Homicidios  \
# 0                    Alaquàs  2021  Valencia                 4           1
# 1                    Alaquàs  2022  Valencia                 5           0
# 2                    Alaquàs  2023  Valencia                13           0
# 3                    Alaquàs  2024  Valencia                 9           2
# 4        Alboraia / Alboraya  2021  Valencia                 3           0
# ..                       ...   ...       ...               ...         ...
# 771  Villanueva de la Cañada  2024    Madrid                12           0
# 772     Villaviciosa de Odón  2021    Madrid                15           0
# 773     Villaviciosa de Odón  2022    Madrid                19           0
# 774     Villaviciosa de Odón  2023    Madrid                11           0
# 775     Villaviciosa de Odón  2024    Madrid                10           0
#
#      Hurtos  Lesiones  Resto De Criminalidad Convencional  Robos Con Fuerza  \
# 0       205         8                                   0               100
# 1       240        14                                   0                99
# 2       178         9                                   0                60
# 3       188         9                                   0                77
# 4       391         4                                   0                86
# ..      ...       ...                                 ...               ...
# 771     231        15                                   0               101
# 772     274        13                                   0               173
# 773     320         8                                   0               182
# 774     301        17                                   0               234
# 775     267        20                                   0               175
#
#      Robos Con Violencia  Secuestro  Sustraccion De Vehiculos  \
# 0                     14          0                        10
# 1                     21          0                        16
# 2                     35          1                         8
# 3                     22          0                        12
# 4                     32          0                        16
# ..                   ...        ...                       ...
# 771                   15          0                         2
# 772                   53          0                         6
# 773                   49          0                         8
# 774                   37          0                         7
# 775                   22          0                         8
#
#      Trafico De Drogas  Total Delitos
# 0                    8            350
# 1                    7            402
# 2                    7            311
# 3                   12            331
# 4                    3            535
# ..                 ...            ...
# 771                  2            378
# 772                  3            537
# 773                  4            590
# 774                  6            613
# 775                  4            506
#
# [776 rows x 14 columns]

# %% [markdown]
# # ES IMPORTANTE NO INCLUIR 2025

# %%
def calculo_estadistico_delitos(df):
    df = df.copy()

    lista_delitos = ["Delitos Sexuales",
                     "Homicidios",
                     "Hurtos",
                     "Lesiones",
                     "Resto De Criminalidad Convencional",
                     "Robos Con Fuerza",
                     "Robos Con Violencia",
                     "Secuestro",
                     "Sustraccion De Vehiculos",
                     "Trafico De Drogas",
                     "Total Delitos"]
   
    df = df.groupby("Geografía")[lista_delitos].mean()

    return df.reset_index()

media_delitos = calculo_estadistico_delitos(df)
media_delitos
# Out:
#                    Geografía  Delitos Sexuales  Homicidios       Hurtos  \
# 0                    Alaquàs          7.750000    0.750000   202.750000
# 1        Alboraia / Alboraya          7.750000    0.000000   519.500000
# 2          Alcalá de Henares         54.777778    5.888889  2499.444444
# 3                 Alcobendas         41.333333    1.777778  1310.333333
# 4                   Alcorcón         33.111111    2.555556  2326.777778
# ..                       ...               ...         ...          ...
# 111          Vilassar de Mar          7.500000    0.250000   130.250000
# 112  Villanueva de la Cañada         12.750000    0.250000   272.500000
# 113     Villaviciosa de Odón         13.750000    0.000000   290.500000
# 114                Xirivella         13.250000    0.750000   299.750000
# 115                   Xàtiva         14.000000    0.750000   315.500000
#
#       Lesiones  Resto De Criminalidad Convencional  Robos Con Fuerza  \
# 0    10.000000                            0.000000         84.000000
# 1    10.000000                            0.000000        139.750000
# 2    53.333333                          174.000000        477.888889
# 3    30.666667                           73.111111        339.888889
# 4    29.555556                           92.777778        356.444444
# ..         ...                                 ...               ...
# 111   4.000000                            0.000000         86.500000
# 112   9.750000                            0.000000        116.500000
# 113  14.500000                            0.000000        191.000000
# 114  14.250000                            0.000000         78.000000
# 115  17.250000                            0.000000        148.250000
#
#      Robos Con Violencia  Secuestro  Sustraccion De Vehiculos  \
# 0              23.000000   0.250000                 11.500000
# 1              36.000000   0.000000                 22.500000
# 2             195.111111   0.222222                203.333333
# 3              92.555556   0.000000                183.444444
# 4             203.777778   0.444444                128.444444
# ..                   ...        ...                       ...
# 111            31.250000   0.000000                 12.250000
# 112            17.000000   0.000000                  4.250000
# 113            40.250000   0.000000                  7.250000
# 114            20.000000   0.000000                 13.000000
# 115            13.250000   0.000000                 16.000000
#
#      Trafico De Drogas  Total Delitos
# 0             8.500000     348.500000
# 1             5.250000     740.750000
# 2            43.222222    3707.222222
# 3            28.444444    2101.555556
# 4            28.555556    3202.444444
# ..                 ...            ...
# 111           1.750000     273.750000
# 112           3.750000     436.750000
# 113           4.250000     561.500000
# 114           3.750000     442.750000
# 115           6.000000     531.000000
#
# [116 rows x 12 columns]
